# %%
import pandas as pd
import sqlite3
from datetime import datetime
import requests
import time
import pandas as pd
import asyncio
from telegram import Bot
import os
from dotenv import load_dotenv
import psycopg2
from sqlalchemy import create_engine
import sqlite3
import asyncio
from telegram import Bot
import numpy as np

# %%
pasta_dados = r'..\pipeline-dados\Dados'

# %%
df = pd.read_json(r"C:\Users\55359\Documents\My Projects\pipeline-dados\Dados\dados_games.jsonl", lines=True, dtype={"preco_anterior": str, "fracao_preco_anterior":str, "preco_atual":str, "fracao_preco_atual":str})

# %%
def limpar_numero(valor):
    if pd.isnull(valor):
        return valor
    return int(str(valor).replace('.', '').replace(',', ''))

# %%
colunas_substituir_none = ['preco_anterior', 'fracao_preco_anterior', 'preco_atual',
       'fracao_preco_atual']

df[colunas_substituir_none] = df[colunas_substituir_none].replace('None', 0)

# %%
df["preco_anterior"] = df["preco_anterior"].apply(limpar_numero)
df["fracao_preco_anterior"] = df["fracao_preco_anterior"].apply(limpar_numero)
df["preco_atual"] = df["preco_atual"].apply(limpar_numero)
df["fracao_preco_atual"] = df["fracao_preco_atual"].apply(limpar_numero)

# %%
df['preco_anterior'] = df["preco_anterior"].astype(str) + "," + df["fracao_preco_anterior"].astype(str)
df['preco_atual'] = df["preco_atual"].astype(str) + "," + df["fracao_preco_atual"].astype(str)

# %%
df = df.drop(columns=['fracao_preco_anterior', 'fracao_preco_atual'])

# %%
df.head(5)
# Out:
#        highlight                                             titulo  \
# 0   MAIS VENDIDO  Console Playstation 5 Midia Fisica Slim Branco...
# 1   BLACK FRIDAY  Microsoft Xbox Series S 512gb Standard Cor Branco
# 2   BLACK FRIDAY  Console Nintendo Switch Oled 64gb Branco Mario...
# 3   MAIS VENDIDO  Microsoft Xbox Series S 512gb Branco  All Digital
# 4   MAIS VENDIDO  Console Playstation 5 Digital Slim Branco 1tb ...
# 5           None  Console Nintendo Switch Oled 64gb Edição Super...
# 6  OFERTA DO DIA          Headset Blackwire C3220 Usb - Plantronics
# 7   MAIS VENDIDO  Headset Qcy H3 Anc Adaptativo Bluetooth 5.3 Mu...
# 8           None         Jbl Fone De Ouvido On Ear Tune 720bt Preto
# 9           None  Console Nintendo Switch Oled 64gb Edição Super...
#
#      vendido_por  nota  total_avaliacoes preco_anterior preco_atual  \
# 0   Por 2Eletro    NaN               NaN        4500,90      3699,0
# 1           None   NaN               NaN        3848,41      2490,0
# 2  Por Nintendo    NaN               NaN        3120,99      2299,0
# 3     Por Eshop    NaN               NaN        3494,90      2629,0
# 4     Por Eshop    NaN               NaN        4400,30      3433,0
# 5  Por Nintendo    NaN               NaN        3090,32      2190,0
# 6  Por TNT Info    NaN               NaN         204,90      197,94
# 7           None   NaN               NaN         329,52      289,52
# 8   Por 2Eletro    NaN               NaN         371,59       319,0
# 9  Por Nintendo    NaN               NaN        3190,91      2299,0
#
#   porcentagem_desconto detalhe_envio        detalhe_envio_2
# 0              17% OFF          None  Chegará grátis amanhã
# 1              35% OFF          None           Frete grátis
# 2              26% OFF          None           Frete grátis
# 3              24% OFF          None           Frete grátis
# 4              21% OFF  Frete grátis                   None
# 5              29% OFF          None           Frete grátis
# 6               3% OFF  Frete grátis                   None
# 7              12% OFF          None           Frete grátis
# 8              14% OFF          None  Chegará grátis amanhã
# 9              27% OFF          None           Frete grátis
